# %% [markdown]
# # <center>Project_05: Micro-Credit Defaulter Model<center>
# ---

# %% [markdown]
# ### Problem Statement:
#
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.
# Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
#
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
#
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour. They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
#
# In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.
#
# ### Exercise:
# Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount within 5 days of insurance of loan. In this case, Label ‘1’ indicates that the loan has been payed i.e. Non- defaulter, while, Label ‘0’ indicates that the loan has not been payed i.e. defaulter.
# ***

# %% [markdown]
# **Importing required libraries:-**

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
# Importing dataset CSV file using pandas
df= pd.read_csv('Data file.csv')

# %%
print('No. of Rows :',df.shape[0])
print('No. of Columns :',df.shape[1])
pd.set_option('display.max_columns',None) # This will enable us to see all columns.
df.head()
# Out:
# No. of Rows : 209593
# No. of Columns : 37
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                 0.0  29.000000  29.000000     UPW  2016-07-20
# 1                 0.0   0.000000   0.000000     UPW  2016-08-10
# 2                 0.0   0.000000   0.000000     UPW  2016-08-19
# 3                 0.0   0.000000   0.000000     UPW  2016-06-06
# 4                 0.0   2.333333   2.333333     UPW  2016-06-22

# %% [markdown]
# ### Data Description:
#
# ![image.png](attachment:image.png)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
#  14  medianamnt_ma_rech30  209593 non-null  float64
#  15  medianmarechprebal30  209593 non-null  float64
#  16  cnt_ma_rech90         209593 non-null  int64
#  17  fr_ma_rech90          209593 non-null  int64
#  18  sumamnt_ma_rech90     209593 non-null  int64
#  19  medianamnt_ma_rech90  209593 non-null  float64
#  20  medianmarechprebal90  209593 non-null  float64
#  21  cnt_da_rech30         209593 non-null  float64
#  22  fr_da_rech30          209593 non-null  float64
#  23  cnt_da_rech90         209593 non-null  int64
#  24  fr_da_rech90          209593 non-null  int64
#  25  cnt_loans30           209593 non-null  int64
#  26  amnt_loans30          209593 non-null  int64
#  27  maxamnt_loans30       209593 non-null  float64
#  28  medianamnt_loans30    209593 non-null  float64
#  29  cnt_loans90           209593 non-null  float64
#  30  amnt_loans90          209593 non-null  int64
#  31  maxamnt_loans90       209593 non-null  int64
#  32  medianamnt_loans90    209593 non-null  float64
#  33  payback30             209593 non-null  float64
#  34  payback90             209593 non-null  float64
#  35  pcircle               209593 non-null  object
#  36  pdate                 209593 non-null  object
# dtypes: float64(21), int64(13), object(3)
# memory usage: 59.2+ MB

# %%
# Let's sort Columns by their datatype:
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Unnamed: 0', 'label', 'last_rech_amt_ma', 'cnt_ma_rech30', 'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30', 'amnt_loans90', 'maxamnt_loans90'], float64: ['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da', 'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30', 'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90'], object: ['msisdn', 'pcircle', 'pdate']}

# %% [markdown]
# #### Observation:
# - **This dataset contain 209593 rows and 37 columns.**
# - **We have 3 features with object datatype and rest features are int64.**
# - **Our target feature is 'label' with 'int' datatype.**
# - **Drop the Unnamed column due to its no significant relation in model building.**

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# **We will perform simple feature engineering on 'pdate' column to create new columns for day,month and year.**

# %%
# Converting Date datatypes and spliting date into date, month and year.
df['pdate']=pd.to_datetime(df['pdate'])
df['Day']=df['pdate'].apply(lambda x:x.day)
df['Month']=df['pdate'].apply(lambda x:x.month)
df['Year']=df['pdate'].apply(lambda x:x.year)
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle      pdate  Day  Month  \
# 0                 0.0  29.000000  29.000000     UPW 2016-07-20   20      7
# 1                 0.0   0.000000   0.000000     UPW 2016-08-10   10      8
# 2                 0.0   0.000000   0.000000     UPW 2016-08-19   19      8
# 3                 0.0   0.000000   0.000000     UPW 2016-06-06    6      6
# 4                 0.0   2.333333   2.333333     UPW 2016-06-22   22      6
#
#    Year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
# Droping pdate column after extraction
df.drop(['pdate'],axis=1,inplace=True)

# %%
df.drop(['Year'],axis=1,inplace=True)

# %% [markdown]
# ### Data Integrity Check

# %%
df.duplicated().sum() # This will check the duplicate data for all columns.
# Out:
# 1

# %%
duplicate = df[df.duplicated()]
print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
#         label       msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 198194      1  82741I90849  367.0   3136.666667   3136.666667   3320.95
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 198194   3320.95                1.0                0.0               770
#
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 198194              5           1.0             8666.0                1539.0
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 198194                  96.0              5             1               8666
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 198194                1539.0                  96.0            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 198194           0.0              0             0            4            24
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 198194              6.0                 0.0          4.0            24
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90 pcircle  \
# 198194                6                 0.0      42.75      42.75     UPW
#
#         Day  Month
# 198194   23      7

# %%
# Selecting duplicate rows based on 'msisdn' column:

duplicate = df[df.duplicated('msisdn')]
 
print("Duplicate Rows based on 'msisdn' :")
 
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows based on 'msisdn' :
#         label       msisdn            aon  daily_decr30  daily_decr90  \
# 1902        1  09901I95206     138.000000    900.000000    900.000000
# 2280        1  14791I90583    1659.000000    124.754667    124.754667
# 2395        1  70401I85339    1419.000000    616.160000    619.100000
# 2909        1  40881I89238     108.000000     96.616000     96.616000
# 3674        1  41251I91190     363.000000   8615.000000   8713.490000
# ...       ...          ...            ...           ...           ...
# 209576      1  70448I82734  811881.372822    149.760000    149.760000
# 209577      1  60261I84455    1007.000000   5079.832000   5104.540000
# 209586      1  60331I70370     254.000000  20079.157333  20228.090000
# 209589      1  95583I84455    1075.000000     36.936000     36.936000
# 209590      1  28556I85350    1013.000000  11843.111667  11904.350000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 1902      434.78    434.78                0.0                0.0
# 2280      813.45    813.45                1.0                0.0
# 2395      556.88    589.76                1.0                0.0
# 2909      674.83    674.83               48.0                0.0
# 3674      498.81   2356.11                5.0                0.0
# ...          ...       ...                ...                ...
# 209576    922.20    922.20                4.0                0.0
# 209577   2844.84   3064.68                2.0                0.0
# 209586   4003.12   5173.74                2.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 1902                   0              0           0.0                0.0
# 2280                4048              5           0.0             9612.0
# 2395                 773              5           6.0             6160.0
# 2909               11327              0           0.0                0.0
# 3674                 770              4           9.0             3849.0
# ...                  ...            ...           ...                ...
# 209576             12500              3           9.0            26567.0
# 209577              1539             10           3.0            11560.0
# 209586              1539              9           4.0            17243.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 1902                     0.0                  0.00              0
# 2280                  2309.0                 16.07              6
# 2395                  1539.0                 32.00              6
# 2909                     0.0                  0.00              1
# 3674                   770.0                 27.50             10
# ...                      ...                   ...            ...
# 209576               10000.0                161.00              3
# 209577                1156.0                 68.70             15
# 209586                1547.0                 37.00             17
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 1902               0                  0                   0.0
# 2280              31              11332                2014.5
# 2395              53               6933                1156.0
# 2909               0              11327               11327.0
# 3674               2              12499                1539.0
# ...              ...                ...                   ...
# 209576             9              26567               10000.0
# 209577             3              16191                 773.0
# 209586             2              33719                1547.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 1902                    0.00            0.0           0.0              0
# 2280                   19.57            0.0           0.0              0
# 2395                   44.50            0.0           0.0              0
# 2909                   43.00            0.0           0.0              0
# 3674                   28.00            0.0           0.0              0
# ...                      ...            ...           ...            ...
# 209576                161.00            0.0           0.0              0
# 209577                 69.20            0.0           0.0              0
# 209586                 37.00            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1902               0            1             6              6.0
# 2280               0            3            18              6.0
# 2395               0            4            24              6.0
# 2909               0            2            12              6.0
# 3674               0            4            24              6.0
# ...              ...          ...           ...              ...
# 209576             0            2            12              6.0
# 209577             0            6            36              6.0
# 209586             0            6            66             12.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1902                   0.0          1.0             6                6
# 2280                   0.0          3.0            18                6
# 2395                   0.5          4.0            24                6
# 2909                   0.0          2.0            12                6
# 3674                   0.0          8.0            48                6
# ...                    ...          ...           ...              ...
# 209576                 0.0          2.0            12                6
# 209577                 0.0          6.0            36                6
# 209586                 0.0         15.0           120               12
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
#
#         medianamnt_loans90  payback30  payback90 pcircle  Day  Month
# 1902                   0.0   0.000000   0.000000     UPW   17      8
# 2280                   0.0   2.333333   2.333333     UPW   11      6
# 2395                   0.5   8.500000   8.500000     UPW    2      7
# 2909                   0.0   0.000000   0.000000     UPW   13      6
# 3674                   0.0   4.666667   4.000000     UPW    1      8
# ...                    ...        ...        ...     ...  ...    ...
# 209576                 0.0   5.500000   5.500000     UPW   15      6
# 209577                 0.0   1.600000   1.600000     UPW    6      7
# 209586                 0.0   3.000000   2.400000     UPW   22      7
# 209589                 0.0   1.000000   1.000000     UPW   12      6
# 209590                 0.0   4.000000   3.833333     UPW   29      7
#
# [23350 rows x 37 columns]

# %%
df.duplicated('msisdn').sum()  # This will check the duplicate data for all columns.
# Out:
# 23350

# %% [markdown]
# - **There 1 row with completely duplicate values of all features.**
# - We will drop 1 row of duplicate entries before going further.
#
# - **There 23350 rows with duplicate mobile number.**
# <u>Training model on duplicate data will inflate accuracy model and additional it will increase computational resources consumption and computational time</u>.
#
# - ***For 23350 entry it is possible that same mobile number is used by customer or telecom company.***
# - ***Another observation is that, for these duplicate entries the other feature values are different from each other.***

# %%
# Droping duplicate entries
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum() # This will check the duplicate data for all columns.
# Out:
# 0

# %%
df.shape
# Out:
# (209592, 37)

# %% [markdown]
# #### Check for presense of any whitespaces, '?', 'NA', '-' in dataset

# %%
df.isin(['NA','N/A','-',' ','?',' ?']).sum().any()
# Out:
# False

# %% [markdown]
# **No White space, 'NA', '-' exist in dataset.**

# %% [markdown]
# ### Missing Value Check

# %%
sns.set_palette('coolwarm')
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# **No Missing value present in dataset.**
#
# **Yes To Go Further !!!**

# %% [markdown]
# ### Statistical Matrix

# %%
df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_3cc92_row0_col0, #T_3cc92_row0_col1, #T_3cc92_row0_col2, #T_3cc92_row0_col5, #T_3cc92_row1_col0, #T_3cc92_row2_col0, #T_3cc92_row3_col0, #T_3cc92_row4_col0, #T_3cc92_row5_col0, #T_3cc92_row6_col0, #T_3cc92_row6_col5, #T_3cc92_row7_col0, #T_3cc92_row7_col5, #T_3cc92_row8_col0, #T_3cc92_row9_col0, #T_3cc92_row9_col1, #T_3cc92_row9_col2, #T_3cc92_row9_col5, #T_3cc92_row10_col0, #T_3cc92_row10_col5, #T_3cc92_row11_col0, #T_3cc92_row12_col0, #T_3cc92_row13_col0, #T_3cc92_row14_col0, #T_3cc92_row14_col1, #T_3cc92_row14_col2, #T_3cc92_row14_col5, #T_3cc92_row15_col0, #T_3cc92_row15_col1, #T_3cc92_row15_col2, #T_3cc92_row15_col5, #T_3cc92_row16_col0, #T_3cc92_row17_col0, #T_3cc92_row18_col0, #T_3cc92_row19_col0, #T_3cc92_row19_col5, #T_3cc92_row20_col0, #T_3cc92_row20_col5, #T_3cc92_row21_col0, #T_3cc92_row21_col1, #T_3cc92_row21_col2, #T_3cc92_row21_col5, #T_3cc92_row22_col0, #T_3cc92_row22_col1, #T_3cc92_row22_col2, #T_3cc92_row22_col5, #T_3cc92_row23_col0, #T_3cc92_row23_col1, #T_3cc92_row23_col2, #T_3cc92_row23_col5, #T_3cc92_row24_col0, #T_3cc92_row24_col1, #T_3cc92_row24_col2, #T_3cc92_row24_col5, #T_3cc92_row25_col0, #T_3cc92_row25_col5, #T_3cc92_row26_col0, #T_3cc92_row26_col1, #T_3cc92_row26_col2, #T_3cc92_row26_col5, #T_3cc92_row27_col0, #T_3cc92_row27_col1, #T_3cc92_row27_col2, #T_3cc92_row27_col5, #T_3cc92_row28_col0, #T_3cc92_row28_col1, #T_3cc92_row28_col2, #T_3cc92_row28_col5, #T_3cc92_row29_col0, #T_3cc92_row29_col1, #T_3cc92_row29_col2, #T_3cc92_row29_col5, #T_3cc92_row30_col0, #T_3cc92_row30_col1, #T_3cc92_row30_col2, #T_3cc92_row30_col5, #T_3cc92_row31_col0, #T_3cc92_row31_col1, #T_3cc92_row31_col2, #T_3cc92_row31_col5, #T_3cc92_row32_col0, #T_3cc92_row32_col1, #T_3cc92_row32_col2, #T_3cc92_row32_col5, #T_3cc92_row33_col0, #T_3cc92_row33_col1, #T_3cc92_row33_col2, #T_3cc92_row33_col5, #T_3cc92_row34_col0, #T_3cc92_row34_col1, #T_3cc92_row34_col2, #T_3cc92_row34_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_3cc92_row1_col1 {
#   background-color: #d22891;
#   color: #f1f1f1;
# }
# #T_3cc92_row1_col2, #T_3cc92_row16_col1, #T_3cc92_row16_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_3cc92_row1_col5 {
#   background-color: #feeae7;
#   color: #000000;
# }
# #T_3cc92_row2_col1 {
#   background-color: #f984ab;
#   color: #f1f1f1;
# }
# #T_3cc92_row2_col2 {
#   background-color: #fde1de;
#   color: #000000;
# }
# #T_3cc92_row2_col5 {
#   background-color: #fccfcb;
#   color: #000000;
# }
# #T_3cc92_row3_col1 {
#   background-color: #f76ca3;
#   color: #f1f1f1;
# }
# #T_3cc92_row3_col2 {
#   background-color: #fdddd9;
#   color: #000000;
# }
# #T_3cc92_row3_col5 {
#   background-color: #fcceca;
#   color: #000000;
# }
# #T_3cc92_row4_col1 {
#   background-color: #fcccc8;
#   color: #000000;
# }
# #T_3cc92_row4_col2, #T_3cc92_row19_col2, #T_3cc92_row25_col2 {
#   background-color: #feede9;
#   color: #000000;
# }
# #T_3cc92_row4_col5, #T_3cc92_row17_col1 {
#   background-color: #fddbd7;
#   color: #000000;
# }
# #T_3cc92_row5_col1 {
#   background-color: #fcbcbd;
#   color: #000000;
# }
# #T_3cc92_row5_col2 {
#   background-color: #fee9e6;
#   color: #000000;
# }
# #T_3cc92_row5_col5 {
#   background-color: #fdd3cf;
#   color: #000000;
# }
# #T_3cc92_row6_col1, #T_3cc92_row10_col1, #T_3cc92_row20_col1 {
#   background-color: #fbb5bb;
#   color: #000000;
# }
# #T_3cc92_row6_col2, #T_3cc92_row13_col2, #T_3cc92_row20_col2 {
#   background-color: #bc1085;
#   color: #f1f1f1;
# }
# #T_3cc92_row7_col1 {
#   background-color: #fbb6bc;
#   color: #000000;
# }
# #T_3cc92_row7_col2 {
#   background-color: #bf1387;
#   color: #f1f1f1;
# }
# #T_3cc92_row8_col1 {
#   background-color: #fdd7d4;
#   color: #000000;
# }
# #T_3cc92_row8_col2 {
#   background-color: #fef1ed;
#   color: #000000;
# }
# #T_3cc92_row8_col5, #T_3cc92_row12_col5, #T_3cc92_row17_col5 {
#   background-color: #fccdc9;
#   color: #000000;
# }
# #T_3cc92_row10_col2 {
#   background-color: #bd1186;
#   color: #f1f1f1;
# }
# #T_3cc92_row11_col1 {
#   background-color: #dd3597;
#   color: #f1f1f1;
# }
# #T_3cc92_row11_col2 {
#   background-color: #fddedb;
#   color: #000000;
# }
# #T_3cc92_row11_col5 {
#   background-color: #d82e94;
#   color: #f1f1f1;
# }
# #T_3cc92_row12_col1 {
#   background-color: #fddcd8;
#   color: #000000;
# }
# #T_3cc92_row12_col2, #T_3cc92_row17_col2 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_3cc92_row13_col1 {
#   background-color: #fbb3bb;
#   color: #000000;
# }
# #T_3cc92_row13_col5, #T_3cc92_row18_col1, #T_3cc92_row18_col2, #T_3cc92_row18_col5 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_3cc92_row16_col2 {
#   background-color: #fccbc6;
#   color: #000000;
# }
# #T_3cc92_row19_col1, #T_3cc92_row25_col1 {
#   background-color: #fff3f0;
#   color: #000000;
# }
# </style>
# <table id="T_3cc92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cc92_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_3cc92_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3cc92_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_3cc92_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_3cc92_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_3cc92_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_3cc92_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_3cc92_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cc92_level0_row0" class="row_heading level0 row0" >label</th>
#       <td id="T_3cc92_row0_col0" class="data row0 col0" >209592.000000</td>
#       <td id="T_3cc92_row0_col1" class="data row0 col1" >0.875177</td>
#       <td id="T_3cc92_row0_col2" class="data row0 col2" >0.330519</td>
#       <td id="T_3cc92_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_3cc92_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_3cc92_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_3cc92_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_3cc92_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cc92_level0_row1" class="row_heading level0 row1" >aon</th>
#       <td id="T_3cc92_row1_col0" class="data row1 col0" >209592.000000</td>
#       <td id="T_3cc92_row1_col1" class="data row1 col1" >8112.380399</td>
#       <td id="T_3cc92_row1_col2" class="data row1 col2" >75696.261220</td>
#       <td id="T_3cc92_row1_col3" class="data row1 col3" >-48.000000</td>
#       <td id="T_3cc92_row1_col4" class="data row1 col4" >246.000000</td>
#       <td id="T_3cc92_row1_col5" class="data row1 col5" >527.000000</td>
#       <td id="T_3cc92_row1_col6" class="data row1 col6" >982.000000</td>
#       <td id="T_3cc92_row1_col7" class="data row1 col7" >999860.755168</td>
#     </tr>
#     <tr>
#       <th id="T_3cc92_level0_row2" class="row_heading level0 row2" >daily_decr30</th>
#       <td id="T_3cc92_row2_col0" class="data row2 col0" >209592.000000</td>
#       <td id="T_3cc92_row2_col1" class="data row2 col1" >5381.412999</td>
#       <td id="T_3cc92_row2_col2" class="data row2 col2" >9220.644093</td>
#       <td id="T_3cc92_row2_col3" class="data row2 col3" >-93.012667</td>
#       <td id="T_3cc92_row2_col4" class="data row2 col4" >42.439500</td>
#       <td id="T_3cc92_row2_col5" class="data row2 col5" >1469.091833</td>
#       <td id="T_3cc92_row2_col6" class="data row2 col6" >7244.096000</td>
#       <td id="T_3cc92_row2_col7" class="data row2 col7" >265926.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3cc92_level0_row3" class="row_heading level0 row3" >daily_decr90</th>
#       <td id="T_3cc92_row3_col0" class="data row3 col0" >209592.000000</td>
#       <td id="T_3cc92_row3_col1" class="data row3 col1" >6082.529123</td>
#       <td id="T_3cc92_row3_col2" class="data row3 col2" >10918.836919</td>
#       <td id="T_3cc92_row3_col3" class="data row3 col3" >-93.012667</td>
#       <td id="T_3cc92_row3_col4" class="data row3 col4" >42.691917</td>
#       <td id="T_3cc92_row3_col5" class="data row3 col5" >1500.000000</td>
#       <td id="T_3cc92_row3_col6" class="data row3 col6" >7802.795000</td>
#       <td id

# %%
df.describe(include=object)
# Out:
#              msisdn pcircle
# count        209592  209592
# unique       186243       1
# top     04581I85330     UPW
# freq              7  209592

# %% [markdown]
# #### Observation:
# - **For all features value of mean is greater than median, indicating skewness in features.**
# - **All data belong to year 2016. We can drop year column.**
# - **pcircle contain single unique value UPW, so we can drop this feature.**
# - **The features aon, daily_decr30, daily_decr90 ,rental30, rental30, last_rech_date_ma, last_rech_date_da, cnt_da_rech30, fr_da_rech30, last_rech_amt_ma, maxamnt_loans30, cnt_loans90, payback30, payback90 contain outliers as there are lot difference in max columns and 75% columns.**
# - **aon, daily_decr30, daily_decr90 ,rental30, rental30, last_rech_date_ma, last_rech_date_da, medianmarechprebal90, medianmarechprebal30 features contain negative values in minimum column.**
# - **Maximum aon (age on cellular network in days) observed is 999860.755168 and the minimum is -48.**

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **Here we will handle feature containing negative values.**

# %% [markdown]
# ### Handling 'aon' negative values:

# %%
df['aon'].describe()
# Out:
# count    209592.000000
# mean       8112.380399
# std       75696.261220
# min         -48.000000
# 25%         246.000000
# 50%         527.000000
# 75%         982.000000
# max      999860.755168
# Name: aon, dtype: float64

# %%
df[df['aon']<0].value_counts().sum()
# Out:
# 1539

# %%
df[df['aon'] > 365*7].value_counts().sum()  # Assuming people stay one network for 7 years.
# Out:
# 2089

# %% [markdown]
# ***There are some negative values in minimum column while there is lot of difference between 75% and max column.Max values is 999860days which means 2739.34 year which is not possible at all.***
#
# ***There are 1539 entries with value less than 0.***
#
# **<u>So Feature 'aon' contain error. To resolve this error we are going to handle upper limit through outlier removal.<u>**

# %% [markdown]
# ### There are lot of features which have negative values and higher max value compare to 75 percentile.There is need of some kind common Strategy to handle them based on certain assumption.

# %% [markdown]
# ### Strategy to handle data error in min and max column.
# - **Assumption- All negative values are typing error happen accidentally by type - in front of original value (except feature depicting median).**
#     - **Negative values are converted into absolute value to correct negative typing error whenever applicable except feature depicting median.**
#     - **Upper limit of these features handle by outlier removal.**
#
# ### Now we will convert all negative values into absolute values.

# %%
#Converting all negative values to positive values in above columns
df['aon']=abs(df['aon'])
df['daily_decr30']=abs(df['daily_decr30'])
df['daily_decr90']=abs(df['daily_decr90'])
df['rental30']=abs(df['rental30'])
df['rental90']=abs(df['rental90'])
df['last_rech_date_ma']=abs(df['last_rech_date_ma'])
df['last_rech_date_da']=abs(df['last_rech_date_da'])
df['medianmarechprebal30']=abs(df['medianmarechprebal30'])
df['medianmarechprebal90']=abs(df['medianmarechprebal90'])

# %% [markdown]
# **We have successfully converted negative data into positive data.**

# %% [markdown]
# ### Another data error contain in maxamnt_loans30 column
#
# **maxamnt_loans30** : maximum amount of loan taken by the user in last 30 days

# %%
df['maxamnt_loans30'].describe()
# Out:
# count    209592.000000
# mean        274.660029
# std        4245.274734
# min           0.000000
# 25%           6.000000
# 50%           6.000000
# 75%           6.000000
# max       99864.560864
# Name: maxamnt_loans30, dtype: float64

# %% [markdown]
# **We already know maximum loan amount taken by customers can be 0,5,10 and which can be repay with amount of 0,6,12. We gone replace values greater than 12 into category of zero.**
#
# **<u>We are making assumption here that loan amount greater than 12 to be replace with zero.</u>**

# %%
df.loc[(df['maxamnt_loans30'] != 6.0) & (df['maxamnt_loans30'] != 12.0)
       & (df['maxamnt_loans30']!=0.0), 'maxamnt_loans30']=0.0

# marking values greater than 12 and assign value zero to them.

# %%
df['maxamnt_loans30'].value_counts()
# Out:
# 6.0     179192
# 12.0     26109
# 0.0       4291
# Name: maxamnt_loans30, dtype: int64

# %% [markdown]
# ### Clearification on negative minimum values in 'medianmarechprebal30' and 'medianmarechprebal90'
#
# **medianmarechprebal90** : Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
#
# **medianmarechprebal90** : Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
# - **Comment** :
#     - **The median of main account balance can be negative.**
#     - **There are some very large positive values in the variable. These could be natural outliers.**

# %% [markdown]
# ### Clearification on extreme max values in cnt_loans30 & cnt_loans90
# **cnt_loans30** : Number of loans taken by user in last 30 days
#
# **cnt_loans90** : Number of loans taken by user in last 90 days
#
# - **Comment**:
#     **There are no information about any restrictions on the number of times a customer can avail loans. Hence these extreme values can be considered as realistic.**

# %% [markdown]
# ### Data is clean and error free now So we will import data in new CSV file and use new CSV file for further investigation.
#
# #### Note :- Outliers will be removed in feature engineering section.

# %%
# Saving error free data to new CSV file with name Clean_data_file
df.to_csv('Clean_data_file.csv',sep=',',index=False)

# %% [markdown]
# # Importing Clean_data_file CSV file through pandas

# %%
df=pd.read_csv('Clean_data_file.csv')

# %%
print('No. of Rows :',df.shape[0])
print('No. of Columns :',df.shape[1])
pd.set_option('display.max_columns',None) # # This will enable us to see truncated columns
df.head()
# Out:
# No. of Rows : 209592
# No. of Columns : 37
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle  Day  Month
# 0                 0.0  29.000000  29.000000     UPW   20      7
# 1                 0.0   0.000000   0.000000     UPW   10      8
# 2                 0.0   0.000000   0.000000     UPW   19      8
# 3                 0.0   0.000000   0.000000     UPW    6      6
# 4                 0.0   2.333333   2.333333     UPW   22      6

# %% [markdown]
# # EDA

# %%
#Counting the number of defaulter and non-defaulter
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(12,6))

df['label'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Label Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('label',data=df,ax=ax[1])
ax[1].set_title('Target Variable Label Distribution',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Label Class",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Customer",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# - **Label class 1 represent Non-defaulter while Label class 0 represent Defaulter i.e. Loan not paid**
# - **We can see Most of customers are Non-defaulter while very few are defaulter.**
# - **From ML model building point of view target variable is imbalanced data case.**

# %%
#Counting the number of defaulter and non-defaulter
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(12,6))

df['Month'].value_counts().plot.pie(explode=[0,0.05,0.05],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Monthwise Customer Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

sns.countplot('Month',hue='label',data=df,ax=ax[1])
ax[1].set_title('Month Vs Default Distribution',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Label-Month",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Customer",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Comment :
#
# - **Most of data belong to month 6 and 7, followed my month 8.**
# - **We can see very few defaulter in month 8.**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,5))
sns.countplot(x='Day',data=df,palette='muted',order= df['Day'].value_counts().index)
plt.title('Data recorded on the basis of days')
plt.xlabel('Days')
plt.ylabel('Count of people')
plt.show()

# %% [markdown]
# **No significant insight from above plot.**

# %%
#Maximum amount of loan taken by people in last 30 and 90 days
plt.figure(figsize = (10,10))
plt.subplot(311)
sns.countplot(x='maxamnt_loans30',data=df,palette='muted',order=df['maxamnt_loans30'].value_counts().index)
plt.title('Maximum amount of loan taken by people in the last 30 days',fontsize=18,fontweight ='bold')
plt.xlabel('Loan amount to be paid',fontsize=18,fontweight ='bold')
plt.ylabel('No. of Customer',fontsize=18,fontweight ='bold')
plt.show()

plt.figure(figsize = (10,10))
plt.subplot(312)
sns.countplot(x='maxamnt_loans90',data=df,palette='Set1',order=df['maxamnt_loans90'].value_counts().index)
plt.title('Maximum amount of loan taken by people in the last 90 days',fontsize=18,fontweight ='bold')
plt.xlabel('Loan amount to be paid',fontsize=18,fontweight ='bold')
plt.ylabel('No. of Customer',fontsize=18,fontweight ='bold')
plt.show()
print(df['maxamnt_loans30'].value_counts())
print('\n')
print(df['maxamnt_loans90'].value_counts())
# Out:
# 6.0     179192
# 12.0     26109
# 0.0       4291
# Name: maxamnt_loans30, dtype: int64
#
#
# 6     180944
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %% [markdown]
# #### Observations:
#
# 1. In 30 days, maximum number of people had taken 6Rs as the loan amount and the number of people is 179192 whereas the  number of people had not taken loan and their number is 4291.
#
# 2. In 90 days, maximum number of people had taken 6Rs as the loan amount and the number of people is 180944 whereas the number of people had not taken loan and their number is 2043.
#
# 3. Maximum number of people had taken 12Rs as the loan amount within 90 days and their number is 26605 whereas for 30 days the number of people who had taken 12Rs is 26109 respectively.
# **This means customer mostly opt for 6 Rs Loan.**

# %%
plt.figure(figsize=(30,18))
pds = sns.countplot(x = "cnt_loans30" ,  data=df)
for p in pds.patches:
    pds.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', size=18, xytext = (0, 20), textcoords = 'offset points')
plt.xticks(rotation= 90)
plt.xlabel("Number of Times loans taken by Customer",fontsize=18,fontweight ='bold')
plt.ylabel("Count " ,size=15)
plt.title ("No of loans taken by users in 30 days" ,fontsize=18,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
pds =sns.countplot(x = "maxamnt_loans90" ,  data=df  , hue= 'label')
for p in pds.patches:
    pds.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', size=18, xytext = (0, 10), textcoords = 'offset points')
plt.xlabel("Amount of loan taken by the user in last 90 days with payback status",fontsize=15,fontweight ='bold')
plt.ylabel("Count " ,size=15)
plt.title ("Customers paid loan amount within 5 days status with label {1:Non-defaulter, 0:defaulter} "
           ,fontsize=15,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Very few defaulter in customers who take loan in amount of 12.**

# %%
#Checking the number of loans taken by people in last 30 days vs Amount of loan taken by the people in last 90 days.
plt.figure(figsize=(18,8))
sns.barplot(x="cnt_loans30",y='amnt_loans30', data=df)
plt.title('Number of loans taken by people in the last 30 days vs Amount of loan taken by people in last 30 days',fontsize=18,fontweight ='bold')
plt.xlabel('Number of loans taken in 30 days',fontsize=18,fontweight ='bold')
plt.ylabel('Amount of loan taken in 30 days',fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# - **Maximum number of loans taken by the people is 50 and the Average loan amount is equivalent to 300.**
#
# - **Minimum number of loans taken by the people is 0.**

# %%
#Checking the maximum number of loans taken vs Amount payed within due dates by people or not on the basis of label
plt.figure(figsize=(18,8))
sns.barplot(x="cnt_loans30",y='payback30',hue='label', data=df)
plt.title('maximum number of loans taken vs Average payback time in last 30 days',fontsize=18,fontweight ='bold')
plt.xlabel('Number of loans taken in 30 days',fontsize=18,fontweight ='bold')
plt.ylabel('Average payback time in days over last 30 days',fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# **We can observe that the Average payback time over last 30 days is higher for people who had taken 2 times the loan and say that the users with less number of loan taking are more than the defaulters**

# %%
plt.figure(figsize=(15,8))
sns.catplot(y = "daily_decr30", x = "Day", data = df.sort_values("daily_decr30", ascending = False),
            kind="boxen", height = 4, aspect = 3)
plt.show()

# %% [markdown]
# # Feature Enginnering

# %%
# As we have 37 Columns Lets sort Columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['label', 'last_rech_amt_ma', 'cnt_ma_rech30', 'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30', 'amnt_loans90', 'maxamnt_loans90', 'Day', 'Month'], float64: ['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da', 'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30', 'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90'], object: ['msisdn', 'pcircle']}

# %%
#Droping PCircle and msisdn column as they are unnecessary for further investigation
df.drop(['msisdn', 'pcircle'],axis=1,inplace=True)

# %% [markdown]
# **As no variable with object datatype is present in database no need for any kind of encoding.**

# %% [markdown]
# ## 1. Outliers Detection and Removal

# %%
plt.figure(figsize=(25,35),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=36:
        ax=plt.subplot(9,4,plotnumber)
        sns.boxplot(df[column],color='gold')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# **From Boxplot outliers exist in dataset.**

# %% [markdown]
# ### Outliers removal using Zscore method

# %%
df1=df.copy()

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df2 = df1[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df1.shape)
print ("Shape of the dataframe after removing outliers: ", df2.shape)
print ("Percentage of data loss post outlier removal: ", (df1.shape[0]-df2.shape[0])/df1.shape[0]*100)

df1=df2.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (209592, 35)
# Shape of the dataframe after removing outliers:  (160499, 35)
# Percentage of data loss post outlier removal:  23.42312683690217

# %% [markdown]
# **Huge amount of data loss in Z-score , which is not acceptable**
#
# **Data loss naturally much higher in IQR compare to Z-score**
#
# **AS outliers are present in upper bound,We need to employ some other outliers removal techinque here.**

# %% [markdown]
# ### Comment :
# - **There outliers exist in data.**
# - **There are no outliers in lower capping level.**
# - **So we will use Quantile-based Flooring and Capping technique.**
#
# ### **We will Employ Quantile-based Flooring and Capping technique for outliers removal. In this technique, we will do the flooring (e.g., the 10th percentile) for the lower values and capping (e.g., the 75th percentile) for the higher values.**

# %%
df.shape
# Out:
# (209592, 35)

# %% [markdown]
# #### **In this dataset, we will set the flooring at 0th percentile for lower bound and capping at 99th percentile for upper bound.**
#
# **Upper bound set as 99th percentile as most of values in dataset are realistic but still there are few very extreme values**
# **No Outliers in lower bound so Lower bound is set as 0th percentile.**

# %%
df1=df.copy()
Q1 = df1.quantile(0)
Q3= df1.quantile(0.99)
IQR = Q3 - Q1
print(IQR)
# Out:
# label                       1.000000
# aon                      2419.090000
# daily_decr30            41730.620000
# daily_decr90            49967.457800
# rental30                19466.008500
# rental90                26997.976500
# last_rech_date_ma          57.000000
# last_rech_date_da          56.000000
# last_rech_amt_ma        10000.000000
# cnt_ma_rech30              20.000000
# fr_ma_rech30               26.000000
# sumamnt_ma_rech30       46857.620000
# medianamnt_ma_rech30    10000.000000
# medianmarechprebal30     1331.545000
# cnt_ma_rech90              33.000000
# fr_ma_rech90               54.000000
# sumamnt_ma_rech90       78717.270000
# medianamnt_ma_rech90    10000.000000
# medianmarechprebal90      840.199700
# cnt_da_rech30               1.000000
# fr_da_rech30                0.000000
# cnt_da_rech90               1.000000
# fr_da_rech90                0.000000
# cnt_loans30                12.000000
# amnt_loans30               84.000000
# maxamnt_loans30            12.000000
# medianamnt_loans30          1.000000
# cnt_loans90                23.000000
# amnt_loans90              132.000000
# maxamnt_loans90            12.000000
# medianamnt_loans90          1.000000
# payback30                  38.666667
# payback90                  49.772500
# Day                        30.000000
# Month                       2.000000
# dtype: float64

# %%
data = df1[~((df1 < (Q1 - 1.5 * IQR)) |(df1 > (Q3 + 1.5 * IQR))).any(axis=1)]
print(data.shape)
# Out:
# (198083, 35)

# %% [markdown]
# ##### Data Loss

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((209592-198174)/209592)*100,'%')
# Out:
# Percentage Data Loss : 5.447727012481392 %

# %% [markdown]
# **We have 5.44% of data Loss with Quantile-based Flooring and Capping Method which is within acceptable range.**
#
# Since outliers are removed we can move further

# %% [markdown]
# ## 2. Skewness of features

# %%
plt.figure(figsize=(25,35),facecolor='white')
plotnumber=1
sns.set_palette('mako')
for column in data:
    if plotnumber<=36:
        ax=plt.subplot(9,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
data.skew()
# Out:
# label                   -2.271744
# aon                      0.953440
# daily_decr30             3.104160
# daily_decr90             3.270636
# rental30                 3.099688
# rental90                 3.255358
# last_rech_date_ma        3.475974
# last_rech_date_da       10.000590
# last_rech_amt_ma         2.299877
# cnt_ma_rech30            2.353749
# fr_ma_rech30             2.022265
# sumamnt_ma_rech30        3.120223
# medianamnt_ma_rech30     2.511528
# medianmarechprebal30     5.978584
# cnt_ma_rech90            2.582953
# fr_ma_rech90             2.283105
# sumamnt_ma_rech90        3.166141
# medianamnt_ma_rech90     2.529071
# medianmarechprebal90     5.285373
# cnt_da_rech30           10.650936
# fr_da_rech30             0.000000
# cnt_da_rech90            7.348862
# fr_da_rech90             0.000000
# cnt_loans30              2.501857
# amnt_loans30             2.643181
# maxamnt_loans30          1.249180
# medianamnt_loans30       4.534271
# cnt_loans90              2.796838
# amnt_loans90             2.875795
# maxamnt_loans90          1.694579
# medianamnt_loans90       4.873642
# payback30                5.953707
# payback90                5.283959
# Day                      0.209544
# Month                    0.348207
# dtype: float64

# %%
df.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'Day', 'Month'],
#       dtype='object')

# %%
# Droping unncessary column
data.drop(['fr_da_rech30'],axis=1,inplace=True)

# %%
# Droping unncessary column
data.drop(['fr_da_rech90'],axis=1,inplace=True)

# %% [markdown]
# **All features are skew except few one like day, month, fr_da_rech90,fr_da_rech30.**
#
# **We will use PowerTransformer to transform skewness in features.**
#
# **We will not perform on label as it is our Target Variable.**

# %%
skew_fea=['aon','daily_decr30', 'daily_decr90', 'rental30','rental90','last_rech_date_ma', 'last_rech_date_da',
          'last_rech_amt_ma','cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30','medianamnt_ma_rech30', 
          'medianmarechprebal30', 'cnt_ma_rech90','fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
          'medianmarechprebal90', 'cnt_da_rech30','cnt_da_rech90', 'cnt_loans30', 'amnt_loans30',
          'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
          'maxamnt_loans90','medianamnt_loans90', 'payback30', 'payback90']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
data[skew_fea] = scaler.fit_transform(data[skew_fea].values)

# %%
data.skew()
# Out:
# label                  -2.271744
# aon                    -0.056836
# daily_decr30           -0.130903
# daily_decr90           -0.120842
# rental30               -0.044544
# rental90               -0.044534
# last_rech_date_ma       0.041762
# last_rech_date_da       6.420203
# last_rech_amt_ma       -0.084106
# cnt_ma_rech30          -0.001251
# fr_ma_rech30            0.136284
# sumamnt_ma_rech30      -0.314463
# medianamnt_ma_rech30   -0.206224
# medianmarechprebal30   -0.033292
# cnt_ma_rech90          -0.003757
# fr_ma_rech90            0.143553
# sumamnt_ma_rech90      -0.214406
# medianamnt_ma_rech90   -0.066437
# medianmarechprebal90   -0.008032
# cnt_da_rech30           9.681533
# cnt_da_rech90           6.688044
# cnt_loans30             0.037006
# amnt_loans30            0.002751
# maxamnt_loans30         0.427556
# medianamnt_loans30      3.452547
# cnt_loans90             0.097548
# amnt_loans90           -0.008132
# maxamnt_loans90         0.367372
# medianamnt_loans90      3.783498
# payback30               0.296047
# payback90               0.208386
# Day                     0.209544
# Month                   0.348207
# dtype: float64

# %% [markdown]
# **Skewness of most of features is reduced.**

# %% [markdown]
# ## 3. Corrleation

# %%
data.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000  0.102145      0.268149      0.270635
# aon                   0.102145  1.000000      0.117940      0.118618
# daily_decr30          0.268149  0.117940      1.000000      0.998269
# daily_decr90          0.270635  0.118618      0.998269      1.000000
# rental30              0.144510  0.084421      0.581144      0.581389
# rental90              0.159662  0.092316      0.637880      0.643187
# last_rech_date_ma     0.067916  0.066396      0.127168      0.131369
# last_rech_date_da     0.027739  0.009534      0.052027      0.052178
# last_rech_amt_ma      0.263424  0.099476      0.377820      0.377301
# cnt_ma_rech30         0.345235  0.040784      0.496389      0.491695
# fr_ma_rech30          0.245409  0.073262      0.300092      0.299318
# sumamnt_ma_rech30     0.358935  0.082753      0.555156      0.549599
# medianamnt_ma_rech30  0.279274  0.099050      0.389979      0.386759
# medianmarechprebal30  0.270786  0.058942      0.280549      0.279118
# cnt_ma_rech90         0.362924  0.062500      0.627494      0.631190
# fr_ma_rech90          0.221390  0.077402      0.221890      0.223084
# sumamnt_ma_rech90     0.368927  0.100981      0.664057      0.667114
# medianamnt_ma_rech90  0.254912  0.104842      0.367290      0.367542
# medianmarechprebal90  0.259199  0.059733      0.248391      0.249150
# cnt_da_rech30         0.015622  0.012668     -0.000266     -0.001206
# cnt_da_rech90         0.024406  0.020937      0.043685      0.043431
# cnt_loans30           0.234263  0.078208      0.340645      0.333892
# amnt_loans30          0.232227  0.078535      0.392409      0.386255
# maxamnt_loans30       0.061453  0.034065      0.297740      0.296533
# medianamnt_loans30    0.046507 -0.002233      0.008628      0.010281
# cnt_loans90           0.269553  0.118883      0.495197      0.495708
# amnt_loans90          0.263550  0.117142      0.524613      0.525301
# maxamnt_loans90       0.069266  0.040889      0.320042      0.320561
# medianamnt_loans90    0.036217 -0.009828     -0.029440     -0.029091
# payback30             0.234539  0.083322      0.329774      0.327209
# payback90             0.242876  0.113321      0.405546      0.406267
# Day                   0.007976  0.016155     -0.011234     -0.018602
# Month                 0.155289  0.086825      0.816979      0.830647
#
#                       rental30  rental90  last_rech_date_ma  \
# label                 0.144510  0.159662           0.067916
# aon                   0.084421  0.092316           0.066396
# daily_decr30          0.581144  0.637880           0.127168
# daily_decr90          0.581389  0.643187           0.131369
# rental30              1.000000  0.973237           0.056639
# rental90              0.973237  1.000000           0.091025
# last_rech_date_ma     0.056639  0.091025           1.000000
# last_rech_date_da     0.016741  0.023896           0.033959
# last_rech_amt_ma      0.284196  0.295692           0.526657
# cnt_ma_rech30         0.455300  0.446845          -0.013990
# fr_ma_rech30          0.252894  0.255113           0.062133
# sumamnt_ma_rech30     0.479560  0.468480           0.118239
# medianamnt_ma_rech30  0.321742  0.313614           0.328661
# medianmarechprebal30  0.229244  0.225984           0.194413
# cnt_ma_rech90         0.510512  0.538759           0.104752
# fr_ma_rech90          0.165138  0.179033           0.221162
# sumamnt_ma_rech90     0.516867  0.543082           0.256654
# medianamnt_ma_rech90  0.271925  0.283016           0.515541
# medianmarechprebal90  0.181708  0.191844           0.345307
# cnt_da_rech30         0.012341  0.006759           0.013805
# cnt_da_rech90         0.010566  0.016237           0.033107
# cnt_loans30           0.310068  0.293297          -0.104965
# amnt_loans30          0.338712  0.326623          -0.106969
# maxamnt_loans30       0.206968  0.214013          -0.021347
# medianamnt_loans30   -0.023199 -0.017937           0.032960
# cnt_loans90           0.401840  0.415618          -0.045948
# amnt_loans90          0.415234  0.430770          -0.053611
# maxamnt_loans90       0.221799  0.233775          -0.013518
# medianamnt_loans90   -0.050662 -0.050165           0.026717
# payback30             0.309139  0.306066          -0.097468
# payback90             0.344427  0.361387          -0.024820
# Day                   0.097946  0.080212           0.030683
# Month                 0.414912  0.503097           0.078121
#
#                       last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# label                          0.027739          0.263424       0.345235
# aon                            0.009534          0.099476       0.040784
# daily_decr30                   0.052027          0.377820       0.496389
# daily_decr90                   0.052178          0.377301       0.491695
# rental30                       0.016741          0.284196       0.455300
# rental90                       0.023896          0.295692       0.446845
# last_rech_date_ma              0.033959          0.526657      -0.013990
# last_rech_date_da              1.000000          0.025398       0.004662
# last_rech_amt_ma               0.025398          1.000000       0.326937
# cnt_ma_rech30                  0.004662          0.326937       1.000000
# fr_ma_rech30                   0.015825          0.278267       0.426235
# sumamnt_ma_rech30              0.012867          0.654763       0.859054
# medianamnt_ma_rech30           0.019493          0.813801       0.420322
# medianmarechprebal30           0.013149          0.434695       0.496741
# cnt_ma_rech90                  0.010298          0.378746       0.921555
# fr_ma_rech90                   0.020485          0.340125       0.226163
# sumamnt_ma_rech90              0.019501          0.703833       0.780343
# medianamnt_ma_rech90           0.025034          0.904280       0.292743
# medianmarechprebal90           0.020136          0.494282       0.397899
# cnt_da_rech30                  0.671426          0.009257      -0.008779
# cnt_da_rech90                  0.961426          0.023939       0.002059
# cnt_loans30                    0.000548          0.146466       0.698686
# amnt_loans30                   0.003597          0.164192       0.693536
# maxamnt_loans30                0.016591          0.130772       0.178290
# medianamnt_loans30             0.007197          0.036136      -0.047811
# cnt_loans90                    0.004675          0.195530       0.694885
# amnt_loans90                   0.006204          0.202122       0.686679
# maxamnt_loans90                0.017372          0.143251       0.183055
# medianamnt_loans90             0.004826          0.023647      -0.062292
# payback30                      0.006197          0.147452       0.546106
# payback90                      0.023802          0.184501       0.491093
# Day                            0.029288          0.057114       0.097425
# Month                          0.037723          0.154155       0.191433
#
#                       fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# label                     0.245409           0.358935              0.279274
# aon                       0.073262           0.082753              0.099050
# daily_decr30              0.300092           0.555156              0.389979
# daily_decr90              0.299318           0.549599              0.386759
# rental30                  0.252894           0.479560              0.321742
# rental90                  0.255113           0.468480              0.313614
# last_rech_date_ma         0.062133           0.118239              0.328661
# last_rech_date_da         0.015825           0.012867              0.019493
# last_rech_amt_ma          0.278267           0.654763              0.813801
# cnt_ma_rech30             0.426235           0.859054              0.420322
# fr_ma_rech30              1.000000           0.465223              0.386007
# sumamnt_ma_rech30         0.465223           1.000000              0.779837
# medianamnt_ma_rech30      0.386007           0.779837              1.000000
# medianmarechprebal30      0.317629           0.579688              0.558828
# cnt_ma_rech90             0.418033           0.805072              0.403914
# fr_ma_rech90              0.619839           0.326286              0.404968
# sumamnt_ma_rech90         0.428233           0.911786              0.696339
# medianamnt_ma_rech90      0.296881           0.639728              0.848870
# medianmarechprebal90      0.234981           0.473106              0.457057
# cnt_da_rech30            -0.000541          -0.000262              0.010238
# cnt_da_rech90             0.014471           0.010832              0.018963
# cnt_loans30               0.299792           0.563078              0.198386
# amnt_loans30              0.283291           0.577632              0.213334
# maxamnt_loans30           0.092904           0.227786              0.146887
# medianamnt_loans30        0.012067          -0.013798              0.039928
# cnt_loans90               0.335486           0.583394              0.244148
# amnt_loans90              0.318516           0.588383              0.249746
# maxamnt_loans90           0.097007           0.238182              0.160190
# medianamnt_loans90       -0.010875          -0.032655              0.022590
# payback30                 0.417132           0.441984              0.195798
# payback90                 0.396058           0.419294              0.231947
# Day                       0.080870           0.100060              0.072811
# Month                     0.134122           0.210506              0.145906
#
#                       medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  \
# label                             0.270786       0.362924      0.221390
# aon                               0.058942       0.062500      0.077402
# daily_decr30                      0.280549       0.627494      0.221890
# daily_decr90                      0.279118       0.631190      0.223084
# rental30                          0.229244       0.510512      0.165138
# rental90                          0.225984       0.538759      0.179033
# last_rech_date_ma                 0.194413       0.104752      0.221162
# last_rech_date_da                 0.013149       0.010298      0.020485
# last_rech_amt_ma                  0.434695       0.378746      0.340125
# cnt_ma_rech30                     0.496741       0.921555      0.226163
# fr_ma_rech30                      0.317629       0.418033      0.619839
# sumamnt_ma_rech30                 0.579688       0.805072      0.326286
# medianamnt_ma_rech30              0.558828       0.403914      0.404968
# medianmarechprebal30              1.000000       0.461809      0.289646
# cnt_ma_rech90                     0.461809       1.000000      0.270985
# fr_ma_rech90                      0.289646       0.270985      1.000000
# sumamnt_ma_rech90                 0.515445       0.868697      0.347220
# medianamnt_ma_rech90              0.440044       0.338913      0.371885
# medianmarechprebal90              0.837323       0.426782      0.256498
# cnt_da_rech30                     0.011805      -0.019053      0.002572
# cnt_da_rech90                     0.012672       0.003949      0.019488
# cnt_loans30                       0.208166       0.650887      0.132123
# amnt_loans30                      0.211273       0.658568      0.115702
# maxamnt_loans30                   0.092302       0.211647      0.026072
# medianamnt_loans30                0.046875      -0.037484      0.029410
# cnt_loans90                       0.236182       0.732454      0.178024
# amnt_loans90                      0.235299       0.730295      0.159715
# maxamnt_loans90                   0.101807       0.228369      0.035744
# medianamnt_loans90                0.035449      -0.067307      0.014560
# payback30                         0.188012       0.515715      0.232080
# payback90                         0.206944       0.509825      0.293633
# Day                               0.052673       0.069430      0.050947
# Month                             0.116774       0.362055      0.107234
#
#                       sumamnt_ma_rech90  medianamnt_ma_rech90  \
# label                          0.368927              0.254912
# aon                            0.100981              0.104842
# daily_decr30                   0.664057              0.367290
# daily_decr90                   0.667114              0.367542
# rental30                       0.516867              0.271925
# rental90                       0.543082              0.283016
# last_rech_date_ma              0.256654              0.515541
# last_rech_date_da              0.019501              0.025034
# last_rech_amt_ma               0.703833              0.904280
# cnt_ma_rech30                  0.780343              0.292743
# fr_ma_rech30                   0.428233              0.296881
# sumamnt_ma_rech30              0.911786              0.639728
# medianamnt_ma_rech30           0.696339              0.848870
# medianmarechprebal30           0.515445              0.440044
# cnt_ma_rech90                  0.868697              0.338913
# fr_ma_rech90                   0.347220              0.371885
# sumamnt_ma_rech90              1.000000              0.706858
# medianamnt_ma_rech90           0.706858              1.000000
# medianmarechprebal90           0.512275              0.505233
# cnt_da_rech30                 -0.008332              0.013380
# cnt_da_rech90                  0.014045              0.024001
# cnt_loans30                    0.516266              0.117628
# amnt_loans30                   0.543169              0.135819
# maxamnt_loans30                0.252881              0.121586
# medianamnt_loans30            -0.006362              0.043011
# cnt_loans90                    0.603439              0.161870
# amnt_loans90                   0.614690              0.169586
# maxamnt_loans90                0.272300              0.133198
# medianamnt_loans90            -0.035577              0.031999
# payback30                      0.402862              0.118525
# payback90                      0.417401              0.157005
# Day                            0.073846              0.059894
# Month                          0.358988              0.150110
#
#                       medianmarechprebal90  cnt_da_rech30  cnt_da_rech90  \
# label                             0.259199       0.015622       0.024406
# aon                               0.059733       0.012668       0.020937
# daily_decr30                      0.248391      -0.000266       0.043685
# daily_decr90                      0.249150      -0.001206       0.043431
# rental30                          0.181708       0.012341       0.010566
# rental90                          0.191844       0.006759       0.016237
# last_rech_date_ma                 0.345307       0.013805       0.033107
# last_rech_date_da                 0.020136       0.671426       0.961426
# last_rech_amt_ma                  0.494282       0.009257       0.023939
# cnt_ma_rech30                     0.397899      -0.008779       0.002059
# fr_ma_rech30                      0.234981      -0.000541       0.014471
# sumamnt_ma_rech30                 0.473106      -0.000262       0.010832
# medianamnt_ma_rech30              0.457057       0.010238       0.018963
# medianmarechprebal30              0.837323       0.011805       0.012672
# cnt_ma_rech90                     0.426782      -0.019053       0.003949
# fr_ma_rech90                      0.256498       0.002572       0.019488
# sumamnt_ma_rech90                 0.512275      -0.008332       0.014045
# medianamnt_ma_rech90              0.505233       0.013380       0.024001
# medianmarechprebal90              1.000000       0.013271       0.020790
# cnt_da_rech30                     0.013271       1.000000       0.698543
# cnt_da_rech90                     0.020790       0.698543       1.000000
# cnt_loans30                       0.152749       0.001434       0.007843
# amnt_loans30                      0.156653       0.000941       0.010155
# maxamnt_loans30                   0.070762       0.002847       0.018518
# medianamnt_loans30                0.053418       0.003996       0.008206
# cnt_loans90                       0.179435      -0.006015       0.011708
# amnt_loans90                      0.179073      -0.005906       0.013080
# maxamnt_loans90                   0.079528       0.003254       0.021149
# medianamnt_loans90                0.047297       0.004976       0.005633
# payback30                         0.131022       0.008228       0.010785
# payback90                         0.147367       0.005906       0.029167
# Day                               0.040639       0.030247       0.029764
# Month                             0.104837      -0.018395       0.025423
#
#                       cnt_loans30  amnt_loans30  maxamnt_loans30  \
# label                    0.234263      0.232227         0.061453
# aon                      0.078208      0.078535         0.034065
# daily_decr30             0.340645      0.392409         0.297740
# daily_decr90             0.333892      0.386255         0.296533
# rental30                 0.310068      0.338712         0.206968
# rental90                 0.293297      0.326623         0.214013
# last_rech_date_ma       -0.104965     -0.106969        -0.021347
# last_rech_date_da        0.000548      0.003597         0.016591
# last_rech_amt_ma         0.146466      0.164192         0.130772
# cnt_ma_rech30            0.698686      0.693536         0.178290
# fr_ma_rech30             0.299792      0.283291         0.092904
# sumamnt_ma_rech30        0.563078      0.577632         0.227786
# medianamnt_ma_rech30     0.198386      0.213334         0.146887
# medianmarechprebal30     0.208166      0.211273         0.092302
# cnt_ma_rech90            0.650887      0.658568         0.211647
# fr_ma_rech90             0.132123      0.115702         0.026072
# sumamnt_ma_rech90        0.516266      0.543169         0.252881
# medianamnt_ma_rech90     0.117628      0.135819         0.121586
# medianmarechprebal90     0.152749      0.156653         0.070762
# cnt_da_rech30            0.001434      0.000941         0.002847
# cnt_da_rech90            0.007843      0.010155         0.018518
# cnt_loans30              1.000000      0.974456         0.282554
# amnt_loans30             0.974456      1.000000         0.456355
# maxamnt_loans30          0.282554      0.456355         1.000000
# medianamnt_loans30      -0.059042     -0.044679         0.051611
# cnt_loans90              0.913171      0.894691         0.268450
# amnt_loans90             0.897772      0.917665         0.403772
# maxamnt_loans90          0.260280      0.435483         0.911008
# medianamnt_loans90      -0.082300     -0.071307         0.020912
# payback30                0.697202      0.650929         0.123991
# payback90                0.602956      0.564199         0.117117
# Day                      0.098068      0.095345         0.024995
# Month                    0.067411      0.125245         0.214148
#
#                       medianamnt_loans30  cnt_loans90  amnt_loans90  \
# label                           0.046507     0.269553      0.263550
# aon                            -0.002233     0.118883      0.117142
# daily_decr30                    0.008628     0.495197      0.524613
# daily_decr90                    0.010281     0.495708      0.525301
# rental30                       -0.023199     0.401840      0.415234
# rental90                       -0.017937     0.415618      0.430770
# last_rech_date_ma               0.032960    -0.045948     -0.053611
# last_rech_date_da               0.007197     0.004675      0.006204
# last_rech_amt_ma                0.036136     0.195530      0.202122
# cnt_ma_rech30                  -0.047811     0.694885      0.686679
# fr_ma_rech30                    0.012067     0.335486      0.318516
# sumamnt_ma_rech30              -0.013798     0.583394      0.588383
# medianamnt_ma_rech30            0.039928     0.244148      0.249746
# medianmarechprebal30            0.046875     0.236182      0.235299
# cnt_ma_rech90                  -0.037484     0.732454      0.730295
# fr_ma_rech90                    0.029410     0.178024      0.159715
# sumamnt_ma_rech90              -0.006362     0.603439      0.614690
# medianamnt_ma_rech90            0.043011     0.161870      0.169586
# medianmarechprebal90            0.053418     0.179435      0.179073
# cnt_da_rech30                   0.003996    -0.006015     -0.005906
# cnt_da_rech90                   0.008206     0.011708      0.013080
# cnt_loans30                    -0.059042     0.913171      0.897772
# amnt_loans30                   -0.044679     0.894691      0.917665
# maxamnt_loans30                 0.051611     0.268450      0.403772
# medianamnt_loans30              1.000000    -0.049717     -0.038565
# cnt_loans90                    -0.049717     1.000000      0.982547
# amnt_loans90                   -0.038565     0.982547      1.000000
# maxamnt_loans90                 0.052589     0.304510      0.451423
# medianamnt_loans90              0.882095    -0.094353     -0.082056
# payback30                      -0.052514     0.704926      0.664987
# payback90                      -0.028593     0.697316      0.655630
# Day                             0.000541     0.078540      0.076622
# Month                           0.031071     0.258320      0.292907
#
#                       maxamnt_loans90  medianamnt_loans90  payback30  \
# label                        0.069266            0.036217   0.234539
# aon                          0.040889           -0.009828   0.083322
# daily_decr30                 0.320042           -0.029440   0.329774
# daily_decr90                 0.320561           -0.029091   0.327209
# rental30                     0.221799           -0.050662   0.309139
# rental90                     0.233775           -0.050165   0.306066
# last_rech_date_ma           -0.013518            0.026717  -0.097468
# last_rech_date_da            0.017372            0.004826   0.006197
# last_rech_amt_ma             0.143251            0.023647   0.147452
# cnt_ma_rech30                0.183055           -0.062292   0.546106
# fr_ma_rech30                 0.097007           -0.010875   0.417132
# sumamnt_ma_rech30            0.238182           -0.032655   0.441984
# medianamnt_ma_rech30         0.160190            0.022590   0.195798
# medianmarechprebal30         0.101807            0.035449   0.188012
# cnt_ma_rech90                0.228369           -0.067307   0.515715
# fr_ma_rech90                 0.035744            0.014560   0.232080
# sumamnt_ma_rech90            0.272300           -0.035577   0.402862
# medianamnt_ma_rech90         0.133198            0.031999   0.118525
# medianmarechprebal90         0.079528            0.047297   0.131022
# cnt_da_rech30                0.003254            0.004976   0.008228
# cnt_da_rech90                0.021149            0.005633   0.010785
# cnt_loans30                  0.260280           -0.082300   0.697202
# amnt_loans30                 0.435483           -0.071307   0.650929
# maxamnt_loans30              0.911008            0.020912   0.123991
# medianamnt_loans30           0.052589            0.882095  -0.052514
# cnt_loans90                  0.304510           -0.094353   0.704926
# amnt_loans90                 0.451423           -0.082056   0.664987
# maxamnt_loans90              1.000000            0.027557   0.124126
# medianamnt_loans90           0.027557            1.000000  -0.084881
# payback30                    0.124126           -0.084881   1.000000
# payback90                    0.142042           -0.076222   0.871001
# Day                          0.020209            0.002138   0.069464
# Month                        0.241914           -0.006746   0.151391
#
#                       payback90       Day     Month
# label                  0.242876  0.007976  0.155289
# aon                    0.113321  0.016155  0.086825
# daily_decr30           0.405546 -0.011234  0.816979
# daily_decr90           0.406267 -0.018602  0.830647
# rental30               0.344427  0.097946  0.414912
# rental90               0.361387  0.080212  0.503097
# last_rech_date_ma     -0.024820  0.030683  0.078121
# last_rech_date_da      0.023802  0.029288  0.037723
# last_rech_amt_ma       0.184501  0.057114  0.154155
# cnt_ma_rech30          0.491093  0.097425  0.191433
# fr_ma_rech30           0.396058  0.080870  0.134122
# sumamnt_ma_rech30      0.419294  0.100060  0.210506
# medianamnt_ma_rech30   0.231947  0.072811  0.145906
# medianmarechprebal30   0.206944  0.052673  0.116774
# cnt_ma_rech90          0.509825  0.069430  0.362055
# fr_ma_rech90           0.293633  0.050947  0.107234
# sumamnt_ma_rech90      0.417401  0.073846  0.358988
# medianamnt_ma_rech90   0.157005  0.059894  0.150110
# medianmarechprebal90   0.147367  0.040639  0.104837
# cnt_da_rech30          0.005906  0.030247 -0.018395
# cnt_da_rech90          0.029167  0.029764  0.025423
# cnt_loans30            0.602956  0.098068  0.067411
# amnt_loans30           0.564199  0.095345  0.125245
# maxamnt_loans30        0.117117  0.024995  0.214148
# medianamnt_loans30    -0.028593  0.000541  0.031071
# cnt_loans90            0.697316  0.078540  0.258320
# amnt_loans90           0.655630  0.076622  0.292907
# maxamnt_loans90        0.142042  0.020209  0.241914
# medianamnt_loans90    -0.076222  0.002138 -0.006746
# payback30              0.871001  0.069464  0.151391
# payback90              1.000000  0.063352  0.254805
# Day                    0.063352  1.000000 -0.253102
# Month                  0.254805 -0.253102  1.000000

# %%
plt.figure(figsize=(25,20))
sns.heatmap(data.corr(),linecolor='black', vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="rainbow")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (24,8))
data.corr()['label'].drop(['label']).sort_values(ascending=False).plot(kind='bar',cmap = 'spring')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('label',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable label',fontsize = 20,fontweight='bold')
plt.show()

# %% [markdown]
# ## 5. Standard Scaling

# %%
# Splitting data in target and dependent feature
X = data.drop(['label'], axis =1)
Y = data['label']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# ## 4. Balanceing Imbalanced target feature

# %%
data.label.value_counts()
# Out:
# 1    173379
# 0     24704
# Name: label, dtype: int64

# %% [markdown]
# <b> As Target variable data is Imbalanced in nature we will need to balance target variable.</b>

# %% [markdown]
# ### Balancing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
data.shape
# Out:
# (198083, 33)

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X_scale, Y = oversample.fit_resample(X_scale, Y)

# %%
Y.value_counts()
# Out:
# 0    173379
# 1    173379
# Name: label, dtype: int64

# %% [markdown]
# **We have successfully resolved the class imbalanced problem and now all the categories have same data ensuring that the ML model does not get biased towards one category.**

# %% [markdown]
# ## 6. Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif
# Out:
#     VIF values              Features
# 0     1.058749                   aon
# 1   784.302763          daily_decr30
# 2   858.456539          daily_decr90
# 3    47.374013              rental30
# 4    52.032861              rental90
# 5     2.935806     last_rech_date_ma
# 6    18.552322     last_rech_date_da
# 7    13.238700      last_rech_amt_ma
# 8    90.031145         cnt_ma_rech30
# 9     2.746214          fr_ma_rech30
# 10  163.132174     sumamnt_ma_rech30
# 11   34.206512  medianamnt_ma_rech30
# 12    8.307835  medianmarechprebal30
# 13  104.307441         cnt_ma_rech90
# 14    2.439354          fr_ma_rech90
# 15  155.668117     sumamnt_ma_rech90
# 16   36.414194  medianamnt_ma_rech90
# 17    7.389151  medianmarechprebal90
# 18    2.005208         cnt_da_rech30
# 19   19.536080         cnt_da_rech90
# 20  219.148808           cnt_loans30
# 21  233.163352          amnt_loans30
# 22    7.694849       maxamnt_loans30
# 23    5.733980    medianamnt_loans30
# 24  328.984384           cnt_loans90
# 25  350.318606          amnt_loans90
# 26   10.484251       maxamnt_loans90
# 27    5.724777    medianamnt_loans90
# 28    7.278560             payback30
# 29    7.069142             payback90
# 30    1.245777                   Day
# 31    6.905264                 Month

# %% [markdown]
# #### Observation :
# - **daily_decr30 and daily_decr90 are highly correlated with each other.**
# - **cnt_loans90 and amnt_loans90 are highly correlated with each other.**
# - **cnt_loans30 and amnt_loans30 are highly correlated with each other.**
# - **cnt_ma_rech30 and sumamnt_ma_rech30 are highly correlated with each other.**

# %% [markdown]
# #### Strategy to Address Multicollinearity :
# 1. Removing Some of highly correlated features. But this will not work here as most of input features are correlated with each other either moderated or poorly.
# 2. Another way to address Multicollinerity is to Scaled Data and then apply PCA.
#
# <b> We will go by Second way for further investigation. As For most Independent feature VIF is exceed permissible limit of 10. </b>

# %% [markdown]
# ## 7. PCA

# %%
#plot the graph to find the principal components
from sklearn.decomposition import PCA
pca =PCA()
x_pca =pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'bo-')
plt.xlabel('Number of components')
plt.ylabel('Variance %')
plt.title('Explained Variance Ratio')
plt.grid()
plt.show()

# %% [markdown]
# #### Comment -
# <b> AS per the graph, we can see that 12 principal components attribute for 90% of variation in the data.  We shall pick the first 12 components for our prediction. </b>

# %%
pca_new = PCA(n_components=11)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(11))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (232327, 11)
# Training target vector size: (232327,)
# Test feature matrix size: (114431, 11)
# Test target vector size: (114431,)

# %% [markdown]
# ## 1.  Logistic Regression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=62, test_size=.33)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.7597067228286042
#
#
# Confusion matrix of Logistics Regression :
#  [[42810 14224]
#  [13273 44124]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.76      0.75      0.76     57034
#            1       0.76      0.77      0.76     57397
#
#     accuracy                           0.76    114431
#    macro avg       0.76      0.76      0.76    114431
# weighted avg       0.76      0.76      0.76    114431

# %% [markdown]
# #### Cross Validation of Logistics Regression

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(log_reg, principle_x, Y, cv =5)
print('\033[1m'+'Cross Validation Score', log_reg, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score LogisticRegression() :
#
# CVScore : [0.75797381 0.75937248 0.75940132 0.76101282 0.75961414]
# Mean CV Score : 0.7594749124090312
# Std deviation : 0.0009647531819595677

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(log_reg,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve ',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, log_reg.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.7596779411776665

# %% [markdown]
# ## 2. Decision Tree Classifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=62, test_size=.33)
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
y_pred=dtc.predict(X_test)
print('\033[1m'+'Decision Tree Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Decision Tree Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Decision Tree Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Decision Tree Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Decision Tree Classifier Evaluation
#
#
# Accuracy Score of Decision Tree Classifier : 0.8543226922774423
#
#
# Confusion matrix of Decision Tree Classifier :
#  [[49768  7266]
#  [ 9404 47993]]
#
#
# classification Report of Decision Tree Classifier
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86     57034
#            1       0.87      0.84      0.85     57397
#
#     accuracy                           0.85    114431
#    macro avg       0.85      0.85      0.85    114431
# weighted avg       0.85      0.85      0.85    114431

# %% [markdown]
# #### Cross Validation of Decision Tree Classifier

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(dtc, principle_x, Y, cv =5)
print('\033[1m'+'Cross Validation Score', dtc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score DecisionTreeClassifier() :
#
# CVScore : [0.86525262 0.86317626 0.86138828 0.86305893 0.86010295]
# Mean CV Score : 0.8625958102488369
# Std deviation : 0.0017482862251153746

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(dtc,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve ',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, dtc.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8543804958236894

# %% [markdown]
# ## 3. Random Forest Classifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=62, test_size=.33)
rfc=RandomForestClassifier()
rfc.fit(X_train,Y_train)
y_pred=rfc.predict(X_test)
print('\033[1m'+'Random Forest Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Random Forest Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Random Forest Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Random Forest Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Random Forest Classifier Evaluation
#
#
# Accuracy Score of Random Forest Classifier : 0.9201702335905481
#
#
# Confusion matrix of Random Forest Classifier :
#  [[53293  3741]
#  [ 5394 52003]]
#
#
# classification Report of Random Forest Classifier
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     57034
#            1       0.93      0.91      0.92     57397
#
#     accuracy                           0.92    114431
#    macro avg       0.92      0.92      0.92    114431
# weighted avg       0.92      0.92      0.92    114431

# %% [markdown]
#  #### Cross Validation Random Forest Classifier

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(rfc, principle_x, Y, cv =5)
print('\033[1m'+'Cross Validation Score', rfc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score RandomForestClassifier() :
#
# CVScore : [0.92647653 0.92875476 0.92921617 0.92695131 0.92741273]
# Mean CV Score : 0.9277622977391632
# Std deviation : 0.0010518410816047399

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(rfc,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve ',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, rfc.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.920215254624235

# %% [markdown]
# ## 4. Extra Tree Classifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=62, test_size=.33)
etc=ExtraTreesClassifier()
etc.fit(X_train,Y_train)
y_pred=etc.predict(X_test)
print('\033[1m'+'Extra Trees Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Extra Trees Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Extra Trees Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Extra Trees Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Extra Trees Classifier Evaluation
#
#
# Accuracy Score of Extra Trees Classifier : 0.934825353269656
#
#
# Confusion matrix of Extra Trees Classifier :
#  [[54059  2975]
#  [ 4483 52914]]
#
#
# classification Report of Extra Trees Classifier
#                precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94     57034
#            1       0.95      0.92      0.93     57397
#
#     accuracy                           0.93    114431
#    macro avg       0.94      0.93      0.93    114431
# weighted avg       0.94      0.93      0.93    114431

# %% [markdown]
# #### Cross Validation Extra Tree Classifier

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(etc, principle_x, Y, cv =5)
print('\033[1m'+'Cross Validation Score', etc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score ExtraTreesClassifier() :
#
# CVScore : [0.94253951 0.94168878 0.94164552 0.94080835 0.94015948]
# Mean CV Score : 0.9413683267038595
# Std deviation : 0.0008156072425260736

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(etc,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve ',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, etc.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.9348665020975452

# %% [markdown]
# **Extra Tree classifier gives maximum accuracy and cross validation score.**

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
             'max_features':['auto','sqrt','log2'] }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START criterion=gini, max_features=auto...........................
# [CV 1/5; 1/6] END criterion=gini, max_features=auto;, score=0.923 total time=  30.0s
# [CV 2/5; 1/6] START criterion=gini, max_features=auto...........................
# [CV 2/5; 1/6] END criterion=gini, max_features=auto;, score=0.926 total time=  30.2s
# [CV 3/5; 1/6] START criterion=gini, max_features=auto...........................
# [CV 3/5; 1/6] END criterion=gini, max_features=auto;, score=0.926 total time=  32.7s
# [CV 4/5; 1/6] START criterion=gini, max_features=auto...........................
# [CV 4/5; 1/6] END criterion=gini, max_features=auto;, score=0.926 total time=  30.2s
# [CV 5/5; 1/6] START criterion=gini, max_features=auto...........................
# [CV 5/5; 1/6] END criterion=gini, max_features=auto;, score=0.924 total time=  29.7s
# [CV 1/5; 2/6] START criterion=gini, max_features=sqrt...........................
# [CV 1/5; 2/6] END criterion=gini, max_features=sqrt;, score=0.925 total time=  30.5s
# [CV 2/5; 2/6] START criterion=gini, max_features=sqrt...........................
# [CV 2/5; 2/6] END criterion=gini, max_features=sqrt;, score=0.927 total time=  29.3s
# [CV 3/5; 2/6] START criterion=gini, max_features=sqrt...........................
# [CV 3/5; 2/6] END criterion=gini, max_features=sqrt;, score=0.927 total time=  30.1s
# [CV 4/5; 2/6] START criterion=gini, max_features=sqrt...........................
# [CV 4/5; 2/6] END criterion=gini, max_features=sqrt;, score=0.925 total time=  29.8s
# [CV 5/5; 2/6] START criterion=gini, max_features=sqrt...........................
# [CV 5/5; 2/6] END criterion=gini, max_features=sqrt;, score=0.923 total time=  29.4s
# [CV 1/5; 3/6] START criterion=gini, max_features=log2...........................
# [CV 1/5; 3/6] END criterion=gini, max_features=log2;, score=0.925 total time=  29.9s
# [CV 2/5; 3/6] START criterion=gini, max_features=log2...........................
# [CV 2/5; 3/6] END criterion=gini, max_features=log2;, score=0.927 total time=  29.7s
# [CV 3/5; 3/6] START criterion=gini, max_features=log2...........................
# [CV 3/5; 3/6] END criterion=gini, max_features=log2;, score=0.926 total time=  31.0s
# [CV 4/5; 3/6] START criterion=gini, max_features=log2...........................
# [CV 4/5; 3/6] END criterion=gini, max_features=log2;, score=0.925 total time=  28.7s
# [CV 5/5; 3/6] START criterion=gini, max_features=log2...........................
# [CV 5/5; 3/6] END criterion=gini, max_features=log2;, score=0.924 total time=  30.4s
# [CV 1/5; 4/6] START criterion=entropy, max_features=auto........................
# [CV 1/5; 4/6] END criterion=entropy, max_features=auto;, score=0.924 total time=  31.3s
# [CV 2/5; 4/6] START criterion=entropy, max_features=auto........................
# [CV 2/5; 4/6] END criterion=entropy, max_features=auto;, score=0.927 total time=  31.9s
# [CV 3/5; 4/6] START criterion=entropy, max_features=auto........................
# [CV 3/5; 4/6] END criterion=entropy, max_features=auto;, score=0.926 total time=  30.9s
# [CV 4/5; 4/6] START criterion=entropy, max_features=auto........................
# [CV 4/5; 4/6] END criterion=entropy, max_features=auto;, score=0.926 total time=  33.0s
# [CV 5/5; 4/6] START criterion=entropy, max_features=auto........................
# [CV 5/5; 4/6] END criterion=entropy, max_features=auto;, score=0.924 total time=  31.4s
# [CV 1/5; 5/6] START criterion=entropy, max_features=sqrt........................
# [CV 1/5; 5/6] END criterion=entropy, max_features=sqrt;, score=0.923 total time=  31.2s
# [CV 2/5; 5/6] START criterion=entropy, max_features=sqrt........................
# [CV 2/5; 5/6] END criterion=entropy, max_features=sqrt;, score=0.926 total time=  30.6s
# [CV 3/5; 5/6] START criterion=entropy, max_features=sqrt........................
# [CV 3/5; 5/6] END criterion=entropy, max_features=sqrt;, score=0.926 total time=  31.5s
# [CV 4/5; 5/6] START criterion=entropy, max_features=sqrt........................
# [CV 4/5; 5/6] END criterion=entropy, max_features=sqrt;, score=0.926 total time=  31.0s
# [CV 5/5; 5/6] START criterion=entropy, max_features=sqrt........................
# [CV 5/5; 5/6] END criterion=entropy, max_features=sqrt;, score=0.924 total time=  31.6s
# [CV 1/5; 6/6] START criterion=entropy, max_features=log2........................
# [CV 1/5; 6/6] END criterion=entropy, max_features=log2;, score=0.924 total time=  31.0s
# [CV 2/5; 6/6] START criterion=entropy, max_features=log2........................
# [CV 2/5; 6/6] END criterion=entropy, max_features=log2;, score=0.926 total time=  30.6s
# [CV 3/5; 6/6] START criterion=entropy, max_features=log2........................
# [CV 3/5; 6/6] END criterion=entropy, max_features=log2;, score=0.926 total time=  31.0s
# [CV 4/5; 6/6] START criterion=entropy, max_features=log2........................
# [CV 4/5; 6/6] END criterion=entropy, max_features=log2;, score=0.925 total time=  31.2s
# [CV 5/5; 6/6] START criterion=entropy, max_features=log2........................
# [CV 5/5; 6/6] END criterion=entropy, max_features=log2;, score=0.925 total time=  31.6s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2']},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt'}

# %% [markdown]
# ## Extra Tree Classifier model based on Hyper Parameter Tuning

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=62, test_size=.33)
etc=ExtraTreesClassifier(criterion='gini', max_features = 'auto')
etc.fit(X_train,Y_train)
y_pred=etc.predict(X_test)
print('\033[1m'+'Extra Trees Classifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Extra Trees Classifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Extra Trees Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Extra Trees Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Extra Trees Classifier Evaluation
#
#
# Accuracy Score of Extra Trees Classifier : 0.9352186033504907
#
#
# Confusion matrix of Extra Trees Classifier :
#  [[54054  2980]
#  [ 4433 52964]]
#
#
# classification Report of Extra Trees Classifier
#                precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94     57034
#            1       0.95      0.92      0.93     57397
#
#     accuracy                           0.94    114431
#    macro avg       0.94      0.94      0.94    114431
# weighted avg       0.94      0.94      0.94    114431

# %% [markdown]
# **We can see that hyper parameter tuning leads to increase in accuracy compare to default parameter from 0.9434 to 0.9445 . We will use New Extra tree classifer model final model.**

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(etc, principle_x, Y, cv =5)
print('\033[1m'+'Cross Validation Score', etc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score ExtraTreesClassifier(max_features='auto') :
#
# CVScore : [0.94277022 0.94294325 0.94129946 0.9406209  0.94134187]
# Mean CV Score : 0.9417951377401346
# Std deviation : 0.0009054187737057059

# %% [markdown]
# ## Final Model AOC ROC

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(etc,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve of Final Model',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, etc.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.9352582314290168

# %% [markdown]
# ## Saving Final Model

# %%
import joblib
joblib.dump(etc,'Micro_Credit_Defaulter_Final.pkl')
# Out:
# ['Micro_Credit_Defaulter_Final.pkl']

# %% [markdown]
# ## Prediction Using Final Model

# %%
# Prediction
prediction = etc.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred
# Out:
#         Predicted Values  Actual Values
# 0                      1              1
# 1                      0              0
# 2                      0              0
# 3                      0              1
# 4                      1              1
# ...                  ...            ...
# 114426                 1              1
# 114427                 0              1
# 114428                 0              0
# 114429                 0              0
# 114430                 1              1
#
# [114431 rows x 2 columns]
